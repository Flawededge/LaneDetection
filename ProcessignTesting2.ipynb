# %%
# This load is based off grabbing all of the videos in a folder and displaying them

from time import sleep
for i in range(1000):
    print(f"\rStatus bar: {i/10}", end='')
    sleep(0.1)
# Out:
# Status bar: 99.9
